# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=-45, horizontalalignment = 'left')
    plt.yticks([])
    #plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    #plt.ylabel('True label')
    #plt.xlabel('Predicted label')

# %% [markdown]
# ### Baseline ####

# %%
#Define labels
class_names = ['coast', 'forest', 'highway', 'insidecity', 'mountain', 'opencountry', 'street', 'tallbuilding']

conf_matrix_base = np.array([[223, 1, 15, 1, 0, 20, 0, 0], [0, 217, 0, 0, 5, 4, 1, 1], [10, 0, 137, 4, 3, 4, 1, 1], [2, 1, 1, 173, 0, 2, 9, 20], [5, 16, 5, 0, 225, 19, 0, 4], [45, 10, 10, 1, 17, 222, 5, 0], [0, 3, 3, 9, 3, 2, 169, 3], [1, 4, 0, 23, 3, 1, 2, 222]])

# Compute confusion matrix
#cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
color = plt.cm.Purples

plt.figure()
plot_confusion_matrix(conf_matrix_base, classes=class_names,
                      title='Confusion matrix - Baseline', cmap = color)

plt.savefig('confMatrix_base.png', format='png', dpi=1000)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[223   1  15   1   0  20   0   0]
#  [  0 217   0   0   5   4   1   1]
#  [ 10   0 137   4   3   4   1   1]
#  [  2   1   1 173   0   2   9  20]
#  [  5  16   5   0 225  19   0   4]
#  [ 45  10  10   1  17 222   5   0]
#  [  0   3   3   9   3   2 169   3]
#  [  1   4   0  23   3   1   2 222]]

# %% [markdown]
# ### CCM ###

# %%
conf_matrix_ccm = np.array([[216, 2, 14, 0, 2, 26, 0, 0], [0, 214, 0, 0, 9, 2, 0, 3], [7, 0, 141, 3, 2, 4, 3, 0], 
                             [3, 1, 5, 165, 0, 5, 11, 18], [8, 16, 5, 0, 215, 24, 2, 4], [43, 14, 10, 3, 13, 217, 7, 3], 
                             [0, 2, 4, 6, 2, 1, 170, 7], [1, 4, 0, 19, 6, 2, 1, 223]])

# Compute confusion matrix
#cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
color = plt.cm.Purples

plt.figure()
plot_confusion_matrix(conf_matrix_ccm, classes=class_names,
                      title='Confusion matrix - CCM', cmap = color)

plt.savefig('confMatrix_CCM.png', format='png', dpi=1000)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[216   2  14   0   2  26   0   0]
#  [  0 214   0   0   9   2   0   3]
#  [  7   0 141   3   2   4   3   0]
#  [  3   1   5 165   0   5  11  18]
#  [  8  16   5   0 215  24   2   4]
#  [ 43  14  10   3  13 217   7   3]
#  [  0   2   4   6   2   1 170   7]
#  [  1   4   0  19   6   2   1 223]]

# %% [markdown]
# ### FE-CCM ###

# %%
conf_matrix_feccm = np.array([[212, 2, 17, 0, 2, 27, 0, 0], [0, 212, 0, 1, 11, 2, 1, 1], [8, 0, 137, 2, 5, 4, 4, 0], 
                             [2, 1, 3, 160, 1, 7, 16, 18], [4, 16, 6, 2, 215, 25, 2, 4], [39, 14, 11, 2, 10, 225, 6, 3], 
                             [0, 2, 2, 6, 3, 2, 170, 7], [1, 6, 1, 23, 6, 3, 1, 215]])


# Compute confusion matrix
#cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
color = plt.cm.Purples

plt.figure()
plot_confusion_matrix(conf_matrix_feccm, classes=class_names,
                      title='Confusion matrix - FE-CCM', cmap = color)

plt.savefig('confMatrix_FECCM.png', format='png', dpi=1000)
plt.show()
# Out:
# Confusion matrix, without normalization
# [[212   2  17   0   2  27   0   0]
#  [  0 212   0   1  11   2   1   1]
#  [  8   0 137   2   5   4   4   0]
#  [  2   1   3 160   1   7  16  18]
#  [  4  16   6   2 215  25   2   4]
#  [ 39  14  11   2  10 225   6   3]
#  [  0   2   2   6   3   2 170   7]
#  [  1   6   1  23   6   3   1 215]]
